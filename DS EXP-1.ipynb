# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/features.csv')

# %%
df
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
df.dtypes
# Out:
# Store             int64
# Date             object
# Temperature     float64
# Fuel_Price      float64
# MarkDown1       float64
# MarkDown2       float64
# MarkDown3       float64
# MarkDown4       float64
# MarkDown5       float64
# CPI             float64
# Unemployment    float64
# IsHoliday          bool
# dtype: object

# %%
df.size
# Out:
# 98280

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2',
#        'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment',
#        'IsHoliday'],
#       dtype='object')

# %%
df.T
# Out:
#                     0           1           2           3           4     \
# Store                  1           1           1           1           1
# Date          2010-02-05  2010-02-12  2010-02-19  2010-02-26  2010-03-05
# Temperature        42.31       38.51       39.93       46.63        46.5
# Fuel_Price         2.572       2.548       2.514       2.561       2.625
# MarkDown1            NaN         NaN         NaN         NaN         NaN
# MarkDown2            NaN         NaN         NaN         NaN         NaN
# MarkDown3            NaN         NaN         NaN         NaN         NaN
# MarkDown4            NaN         NaN         NaN         NaN         NaN
# MarkDown5            NaN         NaN         NaN         NaN         NaN
# CPI           211.096358   211.24217  211.289143  211.319643  211.350143
# Unemployment       8.106       8.106       8.106       8.106       8.106
# IsHoliday          False        True       False       False       False
#
# ...

# %%
df.head(3)
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False

# %%
df.tail(5)
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5  CPI  Unemployment  IsHoliday
# 8185       3.00    2449.97    3169.69  NaN           NaN      False
# 8186     582.74    5797.47    1514.93  NaN           NaN      False
# 8187      85.72     744.84    2150.36  NaN           NaN      False
# 8188     204.19     363.00    1059.46  NaN           NaN      False
# 8189       2.06      10.88    1864.57  NaN           NaN      False

# %%
df1=pd.read_csv('/content/test.csv')

# %%
df1
# Out:
#         Store  Dept        Date  IsHoliday
# 0           1     1  2012-11-02      False
# 1           1     1  2012-11-09      False
# 2           1     1  2012-11-16      False
# 3           1     1  2012-11-23       True
# 4           1     1  2012-11-30      False
# ...       ...   ...         ...        ...
# 115059     45    98  2013-06-28      False
# 115060     45    98  2013-07-05      False
# 115061     45    98  2013-07-12      False
# 115062     45    98  2013-07-19      False
# 115063     45    98  2013-07-26      False
#
# [115064 rows x 4 columns]

# %%
cols=['A','B','C','D','E']
df1 = pd.read_csv('/content/test.csv', names=cols)
df1
# Out:
#             A     B           C          D   E
# 0       Store  Dept        Date  IsHoliday NaN
# 1           1     1  2012-11-02      FALSE NaN
# 2           1     1  2012-11-09      FALSE NaN
# 3           1     1  2012-11-16      FALSE NaN
# 4           1     1  2012-11-23       TRUE NaN
# ...       ...   ...         ...        ...  ..
# 115060     45    98  2013-06-28      FALSE NaN
# 115061     45    98  2013-07-05      FALSE NaN
# 115062     45    98  2013-07-12      FALSE NaN
# 115063     45    98  2013-07-19      FALSE NaN
# 115064     45    98  2013-07-26      FALSE NaN
#
# [115065 rows x 5 columns]

# %%
df3=pd.read_csv('/content/train.csv')
df3
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
df2=pd.read_csv('/content/train.csv', nrows=6)
df2
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False
# 5      1     1  2010-03-12      21043.39      False

# %%
x=df.iloc[2:8, 1:4]
x
# Out:
#          Date  Temperature  Fuel_Price
# 2  2010-02-19        39.93       2.514
# 3  2010-02-26        46.63       2.561
# 4  2010-03-05        46.50       2.625
# 5  2010-03-12        57.79       2.667
# 6  2010-03-19        54.58       2.720
# 7  2010-03-26        51.45       2.732

# %%
df.iloc[2: , 1:]
# Out:
#             Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 2     2010-02-19        39.93       2.514        NaN        NaN        NaN
# 3     2010-02-26        46.63       2.561        NaN        NaN        NaN
# 4     2010-03-05        46.50       2.625        NaN        NaN        NaN
# 5     2010-03-12        57.79       2.667        NaN        NaN        NaN
# 6     2010-03-19        54.58       2.720        NaN        NaN        NaN
# ...          ...          ...         ...        ...        ...        ...
# 8185  2013-06-28        76.05       3.639    4842.29     975.03       3.00
# 8186  2013-07-05        77.50       3.614    9090.48    2268.58     582.74
# 8187  2013-07-12        79.37       3.614    3789.94    1827.31      85.72
# 8188  2013-07-19        82.84       3.737    2961.49    1047.07     204.19
# 8189  2013-07-26        76.06       3.804     212.02     851.73       2.06
#
#       MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
df.iloc[[4,7,8,9], 1:4]
# Out:
#          Date  Temperature  Fuel_Price
# 4  2010-03-05        46.50       2.625
# 7  2010-03-26        51.45       2.732
# 8  2010-04-02        62.27       2.719
# 9  2010-04-09        65.86       2.770

# %%
df.iloc[[4,7,2,8], [3,0,1]]
# Out:
#    Fuel_Price  Store        Date
# 4       2.625      1  2010-03-05
# 7       2.732      1  2010-03-26
# 2       2.514      1  2010-02-19
# 8       2.719      1  2010-04-02

# %%
df.iloc[4, :]
# Out:
# Store                    1
# Date            2010-03-05
# Temperature           46.5
# Fuel_Price           2.625
# MarkDown1              NaN
# MarkDown2              NaN
# MarkDown3              NaN
# MarkDown4              NaN
# MarkDown5              NaN
# CPI             211.350143
# Unemployment         8.106
# IsHoliday            False
# Name: 4, dtype: object

# %%
df.iloc[:,1]
# Out:
# 0       2010-02-05
# 1       2010-02-12
# 2       2010-02-19
# 3       2010-02-26
# 4       2010-03-05
#            ...
# 8185    2013-06-28
# 8186    2013-07-05
# 8187    2013-07-12
# 8188    2013-07-19
# 8189    2013-07-26
# Name: Date, Length: 8190, dtype: object

# %%
df.Store
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 8185    45
# 8186    45
# 8187    45
# 8188    45
# 8189    45
# Name: Store, Length: 8190, dtype: int64

# %%
df.drop([5,8])
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
help(df.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels: 'IndexLabel' = None, *, axis: 'Axis' = 0, index: 'IndexLabel' = None, columns: 'IndexLabel' = None, level: 'Level' = None, inplace: 'bool' = False, errors: 'IgnoreRaise' = 'raise') -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by specifying directly index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level. See the :ref:`user guide <advanced.shown_levels>`
#     for more information about the now unused levels.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop. A tuple will be used as a single
#         label and not treated as a list-like.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %%
df['Store'].mean()
# Out:
# 23.0

# %%
df['Store'].max()
# Out:
# 45

# %%
df['Store'].min()
# Out:
# 1

# %%
df['Store'].sum()
# Out:
# 188370

# %%
df['Store'].median()
# Out:
# 23.0

# %%
df.mean(numeric_only=True)
# Out:
# Store             23.000000
# Temperature       59.356198
# Fuel_Price         3.405992
# MarkDown1       7032.371786
# MarkDown2       3384.176594
# MarkDown3       1760.100180
# MarkDown4       3292.935886
# MarkDown5       4132.216422
# CPI              172.460809
# Unemployment       7.826821
# IsHoliday          0.071429
# dtype: float64

# %%
df.count()
# Out:
# Store           8190
# Date            8190
# Temperature     8190
# Fuel_Price      8190
# MarkDown1       4032
# MarkDown2       2921
# MarkDown3       3613
# MarkDown4       3464
# MarkDown5       4050
# CPI             7605
# Unemployment    7605
# IsHoliday       8190
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
df.describe()
# Out:
#              Store  Temperature   Fuel_Price      MarkDown1      MarkDown2  \
# count  8190.000000  8190.000000  8190.000000    4032.000000    2921.000000
# mean     23.000000    59.356198     3.405992    7032.371786    3384.176594
# std      12.987966    18.678607     0.431337    9262.747448    8793.583016
# min       1.000000    -7.290000     2.472000   -2781.450000    -265.760000
# 25%      12.000000    45.902500     3.041000    1577.532500      68.880000
# 50%      23.000000    60.710000     3.513000    4743.580000     364.570000
# 75%      34.000000    73.880000     3.743000    8923.310000    2153.350000
# max      45.000000   101.950000     4.468000  103184.980000  104519.540000
#
#            MarkDown3     MarkDown4      MarkDown5          CPI  Unemployment
# count    3613.000000   3464.000000    4050.000000  7605.000000   7605.000000
# mean     1760.100180   3292.935886    4132.216422   172.460809      7.826821
# ...

# %%
df['Store']=df['Store'] + 0.52

# %%
df
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1.52  2010-02-05        42.31       2.572        NaN        NaN
# 1      1.52  2010-02-12        38.51       2.548        NaN        NaN
# 2      1.52  2010-02-19        39.93       2.514        NaN        NaN
# 3      1.52  2010-02-26        46.63       2.561        NaN        NaN
# 4      1.52  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185  45.52  2013-06-28        76.05       3.639    4842.29     975.03
# 8186  45.52  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187  45.52  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188  45.52  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189  45.52  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
df['Store']=df['Store'] /10 + 0.27

# %%
df
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0     0.422  2010-02-05        42.31       2.572        NaN        NaN
# 1     0.422  2010-02-12        38.51       2.548        NaN        NaN
# 2     0.422  2010-02-19        39.93       2.514        NaN        NaN
# 3     0.422  2010-02-26        46.63       2.561        NaN        NaN
# 4     0.422  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185  4.822  2013-06-28        76.05       3.639    4842.29     975.03
# 8186  4.822  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187  4.822  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188  4.822  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189  4.822  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
df['Store']=df['Store']=df['Store']/ + 0.27

# %%
df
# Out:
#           Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1.562963  2010-02-05        42.31       2.572        NaN        NaN
# 1      1.562963  2010-02-12        38.51       2.548        NaN        NaN
# 2      1.562963  2010-02-19        39.93       2.514        NaN        NaN
# 3      1.562963  2010-02-26        46.63       2.561        NaN        NaN
# 4      1.562963  2010-03-05        46.50       2.625        NaN        NaN
# ...         ...         ...          ...         ...        ...        ...
# 8185  17.859259  2013-06-28        76.05       3.639    4842.29     975.03
# 8186  17.859259  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187  17.859259  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188  17.859259  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189  17.859259  2013-07-26        76.06       3.804     212.02     851.73
#
# ...

# %%
df=pd.read_csv('/content/features.csv')

# %%
df
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
pd.concat([df,df1])
# Out:
#         Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1.0  2010-02-05        42.31       2.572        NaN        NaN
# 1         1.0  2010-02-12        38.51       2.548        NaN        NaN
# 2         1.0  2010-02-19        39.93       2.514        NaN        NaN
# 3         1.0  2010-02-26        46.63       2.561        NaN        NaN
# 4         1.0  2010-03-05        46.50       2.625        NaN        NaN
# ...       ...         ...          ...         ...        ...        ...
# 115060    NaN         NaN          NaN         NaN        NaN        NaN
# 115061    NaN         NaN          NaN         NaN        NaN        NaN
# 115062    NaN         NaN          NaN         NaN        NaN        NaN
# 115063    NaN         NaN          NaN         NaN        NaN        NaN
# 115064    NaN         NaN          NaN         NaN        NaN        NaN
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment IsHoliday  \
# ...
