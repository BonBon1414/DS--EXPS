# %% [markdown]
# # Data Preprocessing Tools

# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Importing the dataset

# %%
df = pd.read_csv('satellite.csv')
df
# Out:
#       Attribute1  Attribute2  Attribute3  Attribute4  Attribute5  Attribute6  \
# 0             80         102         102          79          76         102
# 1             76         102         102          79          76         102
# 2             80          98         106          79          76          94
# 3             76          94         102          76          76          94
# 4             76          94         102          76          76          94
# ...          ...         ...         ...         ...         ...         ...
# 6430          56          64         108          96          64          71
# 6431          64          71         108          96          68          75
# 6432          68          75         108          96          71          87
# 6433          71          87         108          88          71          91
# 6434          71          91         100          81          76          95
#
# ...

# %%
df_encoded = pd.get_dummies(df, columns=['Attribute1'])
df
# Out:
#       Attribute1  Attribute2  Attribute3  Attribute4  Attribute5  Attribute6  \
# 0             80         102         102          79          76         102
# 1             76         102         102          79          76         102
# 2             80          98         106          79          76          94
# 3             76          94         102          76          76          94
# 4             76          94         102          76          76          94
# ...          ...         ...         ...         ...         ...         ...
# 6430          56          64         108          96          64          71
# 6431          64          71         108          96          68          75
# 6432          68          75         108          96          71          87
# 6433          71          87         108          88          71          91
# 6434          71          91         100          81          76          95
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df.iloc[:, 1:])
df
# Out:
#       Attribute1  Attribute2  Attribute3  Attribute4  Attribute5  Attribute6  \
# 0             80         102         102          79          76         102
# 1             76         102         102          79          76         102
# 2             80          98         106          79          76          94
# 3             76          94         102          76          76          94
# 4             76          94         102          76          76          94
# ...          ...         ...         ...         ...         ...         ...
# 6430          56          64         108          96          64          71
# 6431          64          71         108          96          68          75
# 6432          68          75         108          96          71          87
# 6433          71          87         108          88          71          91
# 6434          71          91         100          81          76          95
#
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
df = pd.read_csv('satellite.csv')
df_encoded = pd.get_dummies(df, columns=['Attribute1'])
X = df_encoded.iloc[:, 1:]
y = df_encoded.iloc[:, 0]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X
# Out:
#       Attribute3  Attribute4  Attribute5  Attribute6  Attribute7  Attribute8  \
# 0            102          79          76         102         102          79
# 1            102          79          76         102         106          83
# 2            106          79          76          94         102          76
# 3            102          76          76          94         102          76
# 4            102          76          76          94         102          76
# ...          ...         ...         ...         ...         ...         ...
# 6430         108          96          64          71         108          96
# 6431         108          96          68          75         108          96
# 6432         108          96          71          87         108          88
# 6433         108          88          71          91         100          81
# 6434         100          81          76          95         108          88
#
# ...

# %%
X_scaled
# Out:
# array([[ 0.16277913, -0.19012792,  0.50513683, ..., -0.04499213,
#         -0.01763227, -0.01246693],
#        [ 0.16277913, -0.19012792,  0.50513683, ..., -0.04499213,
#         -0.01763227, -0.01246693],
#        [ 0.40309659, -0.19012792,  0.50513683, ..., -0.04499213,
#         -0.01763227, -0.01246693],
#        ...,
#        [ 0.52325532,  0.7095236 ,  0.13640918, ..., -0.04499213,
#         -0.01763227, -0.01246693],
#        [ 0.52325532,  0.28615818,  0.13640918, ..., -0.04499213,
#         -0.01763227, -0.01246693],
#        [ 0.0426204 , -0.08428656,  0.50513683, ..., -0.04499213,
#         -0.01763227, -0.01246693]])

# %% [markdown]
# # Normalization

# %%
def normalize(data):
    min_vals = np.min(data, axis=0)
    max_vals = np.max(data, axis=0)
    normalized_data = (data - min_vals) / (max_vals - min_vals)
    return normalized_data
    print(normalized_data)

# %%
print(df)
# Out:
#       Attribute1  Attribute2  Attribute3  Attribute4  Attribute5  Attribute6  \
# 0             80         102         102          79          76         102
# 1             76         102         102          79          76         102
# 2             80          98         106          79          76          94
# 3             76          94         102          76          76          94
# 4             76          94         102          76          76          94
# ...          ...         ...         ...         ...         ...         ...
# 6430          56          64         108          96          64          71
# 6431          64          71         108          96          68          75
# 6432          68          75         108          96          71          87
# 6433          71          87         108          88          71          91
# 6434          71          91         100          81          76          95
#
# ...

# %%
numerical_cols= df.select_dtypes(include=['float64', 'int64']).columns
df[numerical_cols] = (df[numerical_cols] - df[numerical_cols].min()) / (df[numerical_cols].max() - df[numerical_cols].min())

# %%
print(df.head())
# Out:
#    Attribute1  Attribute2  Attribute3  Attribute4  Attribute5  Attribute6  \
# 0    0.630769    0.681818    0.563218    0.380165    0.569231    0.681818
# 1    0.569231    0.681818    0.563218    0.380165    0.569231    0.681818
# 2    0.630769    0.645455    0.609195    0.380165    0.569231    0.609091
# 3    0.569231    0.609091    0.563218    0.355372    0.569231    0.609091
# 4    0.569231    0.609091    0.563218    0.355372    0.569231    0.609091
#
#    Attribute7  Attribute8  Attribute9  Attribute10  ...  Attribute28  \
# 0    0.547368    0.390625      0.5625     0.728155  ...        0.464
# 1    0.589474    0.421875      0.5625     0.728155  ...        0.464
# 2    0.547368    0.367188      0.5625     0.650485  ...        0.400
# 3    0.547368    0.367188      0.5625     0.650485  ...        0.400
# 4    0.547368    0.367188      0.5625     0.601942  ...        0.368
#
#    Attribute29  Attribute30  Attribute31  Attribute32  Attribute33  \
# ...

# %%
print(df.columns)
# Out:
# Index(['Attribute1', 'Attribute2', 'Attribute3', 'Attribute4', 'Attribute5',
#        'Attribute6', 'Attribute7', 'Attribute8', 'Attribute9', 'Attribute10',
#        'Attribute11', 'Attribute12', 'Attribute13', 'Attribute14',
#        'Attribute15', 'Attribute16', 'Attribute17', 'Attribute18',
#        'Attribute19', 'Attribute20', 'Attribute21', 'Attribute22',
#        'Attribute23', 'Attribute24', 'Attribute25', 'Attribute26',
#        'Attribute27', 'Attribute28', 'Attribute29', 'Attribute30',
#        'Attribute31', 'Attribute32', 'Attribute33', 'Attribute34',
#        'Attribute35', 'Attribute36', 'Class'],
#       dtype='object')

# %% [markdown]
# # Balancing the dataset

# %%
from imblearn.over_sampling import RandomOverSampler
X = df.drop('Attribute2', axis=1)
y = df['Attribute2']
y = y.astype(str)
X = pd.get_dummies(X)
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(X, y)
df_resampled = pd.DataFrame(X_resampled, columns=X.columns)
df_resampled['Attribute2'] = y_resampled
print(df_resampled.head())
# Out:
#    Attribute1  Attribute3  Attribute4  Attribute5  Attribute6  Attribute7  \
# 0    0.630769    0.563218    0.380165    0.569231    0.681818    0.547368
# 1    0.569231    0.563218    0.380165    0.569231    0.681818    0.589474
# 2    0.630769    0.609195    0.380165    0.569231    0.609091    0.547368
# 3    0.569231    0.563218    0.355372    0.569231    0.609091    0.547368
# 4    0.569231    0.563218    0.355372    0.569231    0.609091    0.547368
#
#    Attribute8  Attribute9  Attribute10  Attribute11  ...  Attribute29  \
# 0    0.390625      0.5625     0.728155     0.589474  ...     0.615385
# 1    0.421875      0.5625     0.728155     0.589474  ...     0.615385
# 2    0.367188      0.5625     0.650485     0.547368  ...     0.615385
# 3    0.367188      0.5625     0.650485     0.547368  ...     0.615385
# 4    0.367188      0.5625     0.601942     0.463158  ...     0.615385
#
#    Attribute30  Attribute31  Attribute32  Attribute33  Attribute34  \
# ...
