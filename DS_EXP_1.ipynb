# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/games.csv')

# %%
df
# Out:
#          gameId    gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  week
# 0    2018090600  09/06/2018        20:20:00          PHI             ATL     1
# 1    2018090901  09/09/2018        13:00:00          CLE             PIT     1
# 2    2018090902  09/09/2018        13:00:00          IND             CIN     1
# 3    2018090903  09/09/2018        13:00:00          MIA             TEN     1
# 4    2018090900  09/09/2018        13:00:00          BAL             BUF     1
# ..          ...         ...             ...          ...             ...   ...
# 248  2018123013  12/30/2018        16:25:00          DEN             LAC    17
# 249  2018123015  12/30/2018        16:25:00          SEA             ARI    17
# 250  2018123014  12/30/2018        16:25:00           LA              SF    17
# 251  2018122200  12/22/2018        16:30:00          TEN             WAS    16
# 252  2018122201  12/22/2018        20:20:00          LAC             BAL    16
#
# [253 rows x 6 columns]

# %%
df.dtypes
# Out:
# gameId              int64
# gameDate           object
# gameTimeEastern    object
# homeTeamAbbr       object
# visitorTeamAbbr    object
# week                int64
# dtype: object

# %%
df.size
# Out:
# 1518

# %%
df.columns
# Out:
# Index(['gameId', 'gameDate', 'gameTimeEastern', 'homeTeamAbbr',
#        'visitorTeamAbbr', 'week'],
#       dtype='object')

# %%
df.T
# Out:
#                         0           1           2           3           4    \
# gameId           2018090600  2018090901  2018090902  2018090903  2018090900
# gameDate         09/06/2018  09/09/2018  09/09/2018  09/09/2018  09/09/2018
# gameTimeEastern    20:20:00    13:00:00    13:00:00    13:00:00    13:00:00
# homeTeamAbbr            PHI         CLE         IND         MIA         BAL
# visitorTeamAbbr         ATL         PIT         CIN         TEN         BUF
# week                      1           1           1           1           1
#
#                         5           6           7           8           9    \
# gameId           2018090905  2018090907  2018090906  2018090909  2018090910
# gameDate         09/09/2018  09/09/2018  09/09/2018  09/09/2018  09/09/2018
# gameTimeEastern    13:00:00    13:00:00    13:00:00    16:25:00    16:25:00
# homeTeamAbbr             NE         NYG          NO         ARI         CAR
# ...

# %%
df.head(3)
# Out:
#        gameId    gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  week
# 0  2018090600  09/06/2018        20:20:00          PHI             ATL     1
# 1  2018090901  09/09/2018        13:00:00          CLE             PIT     1
# 2  2018090902  09/09/2018        13:00:00          IND             CIN     1

# %%
df.tail(5)
# Out:
#          gameId    gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  week
# 248  2018123013  12/30/2018        16:25:00          DEN             LAC    17
# 249  2018123015  12/30/2018        16:25:00          SEA             ARI    17
# 250  2018123014  12/30/2018        16:25:00           LA              SF    17
# 251  2018122200  12/22/2018        16:30:00          TEN             WAS    16
# 252  2018122201  12/22/2018        20:20:00          LAC             BAL    16

# %%
df1=pd.read_csv('/content/players.csv')

# %%
df1
# Out:
#         nflId height  weight   birthDate             collegeName position  \
# 0     2539334     72     190  1990-09-10              Washington       CB
# 1     2539653     70     186  1988-11-01  Southeastern Louisiana       CB
# 2     2543850     69     186  1991-12-18                  Purdue       SS
# 3     2555162     73     227  1994-11-04         Louisiana State      MLB
# 4     2555255     75     232  1993-07-01               Minnesota      OLB
# ...       ...    ...     ...         ...                     ...      ...
# 1298  2553798    6-2     235  09/17/1991              Vanderbilt       LS
# 1299  2556814    6-2     200  05/17/1994                    Duke       WR
# 1300  2552576     78     231  1992-04-25            Oregon State       QB
# 1301  2561469     69     187  1993-03-15      Alabama-Birmingham       CB
# 1302  2558095    6-2     196  10/12/1995                     LSU       WR
#
#              displayName
# 0        Desmond Trufant
# 1          Robert Alford
# ...

# %%
cols=['A','B','C','D','E']
df1 = pd.read_csv('/content/players.csv', names=cols)
df1
# Out:
#                      A           B                       C         D  \
# nflId   height  weight   birthDate             collegeName  position
# 2539334 72         190  1990-09-10              Washington        CB
# 2539653 70         186  1988-11-01  Southeastern Louisiana        CB
# 2543850 69         186  1991-12-18                  Purdue        SS
# 2555162 73         227  1994-11-04         Louisiana State       MLB
# ...                ...         ...                     ...       ...
# 2553798 6-2        235  09/17/1991              Vanderbilt        LS
# 2556814 6-2        200  05/17/1994                    Duke        WR
# 2552576 78         231  1992-04-25            Oregon State        QB
# 2561469 69         187  1993-03-15      Alabama-Birmingham        CB
# 2558095 6-2        196  10/12/1995                     LSU        WR
#
#                                E
# nflId   height       displayName
# 2539334 72       Desmond Trufant
# 2539653 70         Robert Alford
# ...

# %%
df3=pd.read_csv('/content/plays.csv')
df3
# Out:
#            gameId  playId                                    playDescription  \
# 0      2018090600      75  (15:00) M.Ryan pass short right to J.Jones pus...
# 1      2018090600     146  (13:10) M.Ryan pass incomplete short right to ...
# 2      2018090600     168  (13:05) (Shotgun) M.Ryan pass incomplete short...
# 3      2018090600     190  (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 4      2018090600     256  (10:59) (Shotgun) M.Ryan pass incomplete short...
# ...           ...     ...                                                ...
# 19234  2018122200    2300  (7:53) J.Johnson pass incomplete short left [K...
# 19235  2018122200    3177  (6:53) (Shotgun) B.Gabbert pass incomplete sho...
# 19236  2018122201     566  (5:32) (Shotgun) P.Rivers pass deep right to K...
# 19237  2018122201    1719  (1:08) P.Rivers pass incomplete deep middle to...
# 19238  2018122201    2649  (7:16) (Shotgun) L.Jackson pass incomplete sho...
#
# ...

# %%
df2=pd.read_csv('/content/plays.csv', nrows=6)
df2
# Out:
#        gameId  playId                                    playDescription  \
# 0  2018090600      75  (15:00) M.Ryan pass short right to J.Jones pus...
# 1  2018090600     146  (13:10) M.Ryan pass incomplete short right to ...
# 2  2018090600     168  (13:05) (Shotgun) M.Ryan pass incomplete short...
# 3  2018090600     190  (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 4  2018090600     256  (10:59) (Shotgun) M.Ryan pass incomplete short...
# 5  2018090600     320  (10:10) (Shotgun) N.Foles pass short left to N...
#
#    quarter  down  yardsToGo possessionTeam        playType yardlineSide  \
# 0        1     1         15            ATL  play_type_pass          ATL
# 1        1     1         10            ATL  play_type_pass          PHI
# 2        1     2         10            ATL  play_type_pass          PHI
# 3        1     3         10            ATL  play_type_pass          PHI
# 4        1     3          1            ATL  play_type_pass          PHI
# ...

# %%
x=df.iloc[2:8, 1:4]
x
# Out:
#      gameDate gameTimeEastern homeTeamAbbr
# 2  09/09/2018        13:00:00          IND
# 3  09/09/2018        13:00:00          MIA
# 4  09/09/2018        13:00:00          BAL
# 5  09/09/2018        13:00:00           NE
# 6  09/09/2018        13:00:00          NYG
# 7  09/09/2018        13:00:00           NO

# %%
df.iloc[2: , 1:]
# Out:
#        gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  week
# 2    09/09/2018        13:00:00          IND             CIN     1
# 3    09/09/2018        13:00:00          MIA             TEN     1
# 4    09/09/2018        13:00:00          BAL             BUF     1
# 5    09/09/2018        13:00:00           NE             HOU     1
# 6    09/09/2018        13:00:00          NYG             JAX     1
# ..          ...             ...          ...             ...   ...
# 248  12/30/2018        16:25:00          DEN             LAC    17
# 249  12/30/2018        16:25:00          SEA             ARI    17
# 250  12/30/2018        16:25:00           LA              SF    17
# 251  12/22/2018        16:30:00          TEN             WAS    16
# 252  12/22/2018        20:20:00          LAC             BAL    16
#
# [251 rows x 5 columns]

# %%
df.iloc[[4,7,8,9], 1:4]
# Out:
#      gameDate gameTimeEastern homeTeamAbbr
# 4  09/09/2018        13:00:00          BAL
# 7  09/09/2018        13:00:00           NO
# 8  09/09/2018        16:25:00          ARI
# 9  09/09/2018        16:25:00          CAR

# %%
df.iloc[[4,7,2,8], [3,0,1]]
# Out:
#   homeTeamAbbr      gameId    gameDate
# 4          BAL  2018090900  09/09/2018
# 7           NO  2018090906  09/09/2018
# 2          IND  2018090902  09/09/2018
# 8          ARI  2018090909  09/09/2018

# %%
df.iloc[4, :]
# Out:
# gameId             2018090900
# gameDate           09/09/2018
# gameTimeEastern      13:00:00
# homeTeamAbbr              BAL
# visitorTeamAbbr           BUF
# week                        1
# Name: 4, dtype: object

# %%
df.iloc[:,1]
# Out:
# 0      09/06/2018
# 1      09/09/2018
# 2      09/09/2018
# 3      09/09/2018
# 4      09/09/2018
#           ...
# 248    12/30/2018
# 249    12/30/2018
# 250    12/30/2018
# 251    12/22/2018
# 252    12/22/2018
# Name: gameDate, Length: 253, dtype: object

# %%
df.gameId
# Out:
# 0      2018090600
# 1      2018090901
# 2      2018090902
# 3      2018090903
# 4      2018090900
#           ...
# 248    2018123013
# 249    2018123015
# 250    2018123014
# 251    2018122200
# 252    2018122201
# Name: gameId, Length: 253, dtype: int64

# %%
df.drop([5,8])
# Out:
#          gameId    gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  week
# 0    2018090600  09/06/2018        20:20:00          PHI             ATL     1
# 1    2018090901  09/09/2018        13:00:00          CLE             PIT     1
# 2    2018090902  09/09/2018        13:00:00          IND             CIN     1
# 3    2018090903  09/09/2018        13:00:00          MIA             TEN     1
# 4    2018090900  09/09/2018        13:00:00          BAL             BUF     1
# ..          ...         ...             ...          ...             ...   ...
# 248  2018123013  12/30/2018        16:25:00          DEN             LAC    17
# 249  2018123015  12/30/2018        16:25:00          SEA             ARI    17
# 250  2018123014  12/30/2018        16:25:00           LA              SF    17
# 251  2018122200  12/22/2018        16:30:00          TEN             WAS    16
# 252  2018122201  12/22/2018        20:20:00          LAC             BAL    16
#
# [251 rows x 6 columns]

# %%
help(df.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels: 'IndexLabel | None' = None, *, axis: 'Axis' = 0, index: 'IndexLabel | None' = None, columns: 'IndexLabel | None' = None, level: 'Level | None' = None, inplace: 'bool' = False, errors: 'IgnoreRaise' = 'raise') -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by directly specifying index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level. See the :ref:`user guide <advanced.shown_levels>`
#     for more information about the now unused levels.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop. A tuple will be used as a single
#         label and not treated as a list-like.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %%
df['gameId'].mean()
# Out:
# 2018107811.1027668

# %%
df['gameId'].max()
# Out:
# 2018123015

# %%
df['gameId'].min()
# Out:
# 2018090600

# %%
df['gameId'].sum()
# Out:
# 510581276209

# %%
df['gameId'].median()
# Out:
# 2018110407.0

# %%
df.mean(numeric_only=True)
# Out:
# gameId    2.018108e+09
# week      9.122530e+00
# dtype: float64

# %%
df.count()
# Out:
# gameId             253
# gameDate           253
# gameTimeEastern    253
# homeTeamAbbr       253
# visitorTeamAbbr    253
# week               253
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   gameId           253 non-null    int64
#  1   gameDate         253 non-null    object
#  2   gameTimeEastern  253 non-null    object
#  3   homeTeamAbbr     253 non-null    object
#  4   visitorTeamAbbr  253 non-null    object
#  5   week             253 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 12.0+ KB

# %%
df.describe()
# Out:
#              gameId        week
# count  2.530000e+02  253.000000
# mean   2.018108e+09    9.122530
# std    1.144901e+04    4.979801
# min    2.018091e+09    1.000000
# 25%    2.018101e+09    5.000000
# 50%    2.018110e+09    9.000000
# 75%    2.018121e+09   14.000000
# max    2.018123e+09   17.000000

# %%
df['gameId']=df['gameId'] + 0.52

# %%
df
# Out:
#            gameId    gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  \
# 0    2.018091e+09  09/06/2018        20:20:00          PHI             ATL
# 1    2.018091e+09  09/09/2018        13:00:00          CLE             PIT
# 2    2.018091e+09  09/09/2018        13:00:00          IND             CIN
# 3    2.018091e+09  09/09/2018        13:00:00          MIA             TEN
# 4    2.018091e+09  09/09/2018        13:00:00          BAL             BUF
# ..            ...         ...             ...          ...             ...
# 248  2.018123e+09  12/30/2018        16:25:00          DEN             LAC
# 249  2.018123e+09  12/30/2018        16:25:00          SEA             ARI
# 250  2.018123e+09  12/30/2018        16:25:00           LA              SF
# 251  2.018122e+09  12/22/2018        16:30:00          TEN             WAS
# 252  2.018122e+09  12/22/2018        20:20:00          LAC             BAL
#
#      week
# 0       1
# 1       1
# 2       1
# 3       1
# ...

# %%
df['gameId']=df['gameId'] /10 + 0.27

# %%
df
# Out:
#            gameId    gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  \
# 0    2.018091e+08  09/06/2018        20:20:00          PHI             ATL
# 1    2.018091e+08  09/09/2018        13:00:00          CLE             PIT
# 2    2.018091e+08  09/09/2018        13:00:00          IND             CIN
# 3    2.018091e+08  09/09/2018        13:00:00          MIA             TEN
# 4    2.018091e+08  09/09/2018        13:00:00          BAL             BUF
# ..            ...         ...             ...          ...             ...
# 248  2.018123e+08  12/30/2018        16:25:00          DEN             LAC
# 249  2.018123e+08  12/30/2018        16:25:00          SEA             ARI
# 250  2.018123e+08  12/30/2018        16:25:00           LA              SF
# 251  2.018122e+08  12/22/2018        16:30:00          TEN             WAS
# 252  2.018122e+08  12/22/2018        20:20:00          LAC             BAL
#
#      week
# 0       1
# 1       1
# 2       1
# 3       1
# ...

# %%
df['gameId']=df['gameId']=df['gameId']/ + 0.27

# %%
df
# Out:
#            gameId    gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  \
# 0    7.474410e+08  09/06/2018        20:20:00          PHI             ATL
# 1    7.474411e+08  09/09/2018        13:00:00          CLE             PIT
# 2    7.474411e+08  09/09/2018        13:00:00          IND             CIN
# 3    7.474411e+08  09/09/2018        13:00:00          MIA             TEN
# 4    7.474411e+08  09/09/2018        13:00:00          BAL             BUF
# ..            ...         ...             ...          ...             ...
# 248  7.474530e+08  12/30/2018        16:25:00          DEN             LAC
# 249  7.474530e+08  12/30/2018        16:25:00          SEA             ARI
# 250  7.474530e+08  12/30/2018        16:25:00           LA              SF
# 251  7.474527e+08  12/22/2018        16:30:00          TEN             WAS
# 252  7.474527e+08  12/22/2018        20:20:00          LAC             BAL
#
#      week
# 0       1
# 1       1
# 2       1
# 3       1
# ...

# %%
df=pd.read_csv('/content/games.csv')

# %%
df
# Out:
#          gameId    gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  week
# 0    2018090600  09/06/2018        20:20:00          PHI             ATL     1
# 1    2018090901  09/09/2018        13:00:00          CLE             PIT     1
# 2    2018090902  09/09/2018        13:00:00          IND             CIN     1
# 3    2018090903  09/09/2018        13:00:00          MIA             TEN     1
# 4    2018090900  09/09/2018        13:00:00          BAL             BUF     1
# ..          ...         ...             ...          ...             ...   ...
# 248  2018123013  12/30/2018        16:25:00          DEN             LAC    17
# 249  2018123015  12/30/2018        16:25:00          SEA             ARI    17
# 250  2018123014  12/30/2018        16:25:00           LA              SF    17
# 251  2018122200  12/22/2018        16:30:00          TEN             WAS    16
# 252  2018122201  12/22/2018        20:20:00          LAC             BAL    16
#
# [253 rows x 6 columns]

# %%
pd.concat([df,df1])
# Out:
#                       gameId    gameDate gameTimeEastern homeTeamAbbr  \
# 0               2.018091e+09  09/06/2018        20:20:00          PHI
# 1               2.018091e+09  09/09/2018        13:00:00          CLE
# 2               2.018091e+09  09/09/2018        13:00:00          IND
# 3               2.018091e+09  09/09/2018        13:00:00          MIA
# 4               2.018091e+09  09/09/2018        13:00:00          BAL
# ...                      ...         ...             ...          ...
# (2553798, 6-2)           NaN         NaN             NaN          NaN
# (2556814, 6-2)           NaN         NaN             NaN          NaN
# (2552576, 78)            NaN         NaN             NaN          NaN
# (2561469, 69)            NaN         NaN             NaN          NaN
# (2558095, 6-2)           NaN         NaN             NaN          NaN
#
#                visitorTeamAbbr  week    A           B                   C  \
# ...
